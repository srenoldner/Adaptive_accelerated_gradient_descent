# %%
import urllib.request
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/mushrooms"
urllib.request.urlretrieve(url, "mushrooms")
url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/regression/bodyfat"
urllib.request.urlretrieve(url, "bodyfat")
url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/regression/cadata"
urllib.request.urlretrieve(url, "cadata")
url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/w8a"
urllib.request.urlretrieve(url, "w8a")
url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html#covtype"
urllib.request.urlretrieve(url, "covtype")
# Out:
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7184\2837466612.py in <cell line: 10>()
#       8 urllib.request.urlretrieve(url, "cadata")
#       9 url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/w8a"
# ---> 10 urllib.request.urlretrieve(url, "w8a")
#      11 url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html#covtype"
#      12 urllib.request.urlretrieve(url, "covtype")
#
# C:\WinPython\WPy64-31050\python-3.10.5.amd64\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     278
#     279     if size >= 0 and read < size:
# --> 280         raise ContentTooShortError(
#     281             "retrieval incomplete: got only %i out of %i bytes"
#     282             % (read, size), result)
#
# ...
